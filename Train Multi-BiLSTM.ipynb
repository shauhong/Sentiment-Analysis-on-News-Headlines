# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.optim import Adam
from sklearn.metrics import accuracy_score
from dataset import News
from embedding import GloVe
from model import BiLSTM, AttentionBiLSTM
from utils import save_history, save_checkpoint, load_checkpoint, load_config
from train import train, evaluate

# %%
def main():
    config = load_config()
    print(config)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    path = "data"
    epochs = 50
    
    history = {
        'train': {
            'loss': list(),
            'accuracy': list(),
        },
        'val': {
            'loss': list(),
            'accuracy': list(),
        }
    }
    
    glove = GloVe(**config['GloVe'])
    model = BiLSTM(glove, **config['Multi-BiLSTM'])
    model.to(device)
    optimizer = Adam(model.parameters(), **config['ADAM'])
    criterion = nn.CrossEntropyLoss()
    
    train_dataset = News(path, glove, split='train')
    val_dataset = News(path, glove, split='validation')
    test_dataset = News(path, glove, split='test')
    train_dataloader = DataLoader(train_dataset, collate_fn=train_dataset.collate_fn, **config['train'])
    val_dataloader = DataLoader(val_dataset, collate_fn=val_dataset.collate_fn, **config['validation'])
    test_dataloader = DataLoader(test_dataset, collate_fn=test_dataset.collate_fn, **config['test'])
    
    checkpoint = load_checkpoint()
    if checkpoint:
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        history = checkpoint['history']

    for epoch in range(epochs):
        train_loss, train_accuracy = train(model, train_dataloader, optimizer, criterion, device)
        val_loss, val_accuracy = evaluate(model, val_dataloader, criterion, device)
        
        is_best = True if len(history['val']['accuracy']) > 0 and val_accuracy > max(history['val']['accuracy']) else False
        
        history['train']['loss'].append(train_loss)
        history['train']['accuracy'].append(train_accuracy)
        history['val']['loss'].append(val_loss)                            
        history['val']['accuracy'].append(val_accuracy)
        
        if is_best:
            save_checkpoint(epoch, model, optimizer, history, path="assets/checkpoint_multi-lstm.pt")
            
        print(f"Epoch {epoch + 1}/{epochs}")
        print(f"Loss: {train_loss:.4e}, Accuracy: {train_accuracy:6.2f}, Validation Loss: {val_loss:.4e}, Validation Accuracy: {val_accuracy:6.2f}")
    
    save_history(history, path="assets/history_multi-lstm.pkl")
    
    test_loss, test_accuracy = evaluate(model, test_dataloader, criterion, device)
    print("Test - Final Model")
    print(f"Test Loss: {test_loss:.4e}, Test Accuracy: {test_accuracy:6.2f}")
    
    checkpoint = load_checkpoint(path="assets/checkpoint_multi-lstm.pt")
    model.load_state_dict(checkpoint['model_state_dict'])
    test_loss, test_accuracy = evaluate(model, test_dataloader, criterion, device)
    print("Test - Best Model")
    print(f"Test Loss: {test_loss:.4e}, Test Accuracy: {test_accuracy:6.2f}")

# %%
main()
# Out:
# {'ADAM': {'betas': (0.9, 0.999), 'eps': 1e-08, 'lr': 0.001, 'weight_decay': 0.001}, 'SGD': {'lr': 0.01, 'weight_decay': 1e-05, 'momentum': 0.9}, 'GloVe': {'variant': 'glove-wiki-gigaword-300'}, 'LSTM': {'bidirectional': True, 'freeze': True, 'hidden_size': 64, 'dropout_rate': 0.3, 'n_classes': 3, 'num_layers': 1}, 'Multi-LSTM': {'bidirectional': True, 'freeze': True, 'hidden_size': 64, 'dropout_rate': 0.5, 'n_classes': 3, 'num_layers': 2}, 'Attention-LSTM': {'bidirectional': True, 'freeze': True, 'hidden_size': 64, 'dropout_rate': 0.5, 'n_classes': 3, 'num_layers': 1}, 'Attention-Multi-LSTM': {'bidirectional': True, 'freeze': True, 'hidden_size': 64, 'dropout_rate': 0.5, 'n_classes': 3, 'num_layers': 2}, 'train': {'batch_size': 32, 'shuffle': True}, 'validation': {'batch_size': 32, 'shuffle': False}, 'test': {'batch_size': 32, 'shuffle': False}}
# Epoch 1/50
# Loss: 8.4318e-01, Accuracy:   0.61, Validation Loss: 8.7489e-01, Validation Accuracy:   0.55
# Epoch 2/50
# Loss: 7.7758e-01, Accuracy:   0.65, Validation Loss: 8.2817e-01, Validation Accuracy:   0.60
# Epoch 3/50
# Loss: 7.5035e-01, Accuracy:   0.67, Validation Loss: 8.5020e-01, Validation Accuracy:   0.57
# Epoch 4/50
# Loss: 7.3316e-01, Accuracy:   0.68, Validation Loss: 8.4055e-01, Validation Accuracy:   0.57
# Epoch 5/50
# Loss: 7.2445e-01, Accuracy:   0.69, Validation Loss: 8.8918e-01, Validation Accuracy:   0.56
# Epoch 6/50
# Loss: 7.1655e-01, Accuracy:   0.69, Validation Loss: 9.0245e-01, Validation Accuracy:   0.55
# Epoch 7/50
# Loss: 7.1076e-01, Accuracy:   0.69, Validation Loss: 8.8225e-01, Validation Accuracy:   0.55
# Epoch 8/50
# Loss: 7.0528e-01, Accuracy:   0.70, Validation Loss: 8.0143e-01, Validation Accuracy:   0.58
# Epoch 9/50
# Loss: 7.0235e-01, Accuracy:   0.70, Validation Loss: 8.5857e-01, Validation Accuracy:   0.56
# Epoch 10/50
# Loss: 6.9858e-01, Accuracy:   0.70, Validation Loss: 8.2243e-01, Validation Accuracy:   0.59
# Epoch 11/50
# Loss: 6.9427e-01, Accuracy:   0.70, Validation Loss: 8.3084e-01, Validation Accuracy:   0.57
# Epoch 12/50
# Loss: 6.9246e-01, Accuracy:   0.70, Validation Loss: 8.5452e-01, Validation Accuracy:   0.58
# Epoch 13/50
# Loss: 6.8737e-01, Accuracy:   0.71, Validation Loss: 9.2283e-01, Validation Accuracy:   0.56
# Epoch 14/50
# Loss: 6.8840e-01, Accuracy:   0.71, Validation Loss: 8.4334e-01, Validation Accuracy:   0.59
# Epoch 15/50
# Loss: 6.8598e-01, Accuracy:   0.71, Validation Loss: 8.6523e-01, Validation Accuracy:   0.57
# Epoch 16/50
# Loss: 6.8411e-01, Accuracy:   0.71, Validation Loss: 8.4500e-01, Validation Accuracy:   0.58
# Epoch 17/50
# Loss: 6.8223e-01, Accuracy:   0.71, Validation Loss: 8.5337e-01, Validation Accuracy:   0.58
# Epoch 18/50
# Loss: 6.8099e-01, Accuracy:   0.71, Validation Loss: 9.3794e-01, Validation Accuracy:   0.55
# Epoch 19/50
# Loss: 6.7988e-01, Accuracy:   0.71, Validation Loss: 8.4546e-01, Validation Accuracy:   0.58
# Epoch 20/50
# Loss: 6.8000e-01, Accuracy:   0.71, Validation Loss: 8.8188e-01, Validation Accuracy:   0.56
# Epoch 21/50
# Loss: 6.7933e-01, Accuracy:   0.71, Validation Loss: 8.6973e-01, Validation Accuracy:   0.57
# Epoch 22/50
# Loss: 6.7723e-01, Accuracy:   0.71, Validation Loss: 9.2609e-01, Validation Accuracy:   0.54
# Epoch 23/50
# Loss: 6.7594e-01, Accuracy:   0.71, Validation Loss: 9.3876e-01, Validation Accuracy:   0.55
# Epoch 24/50
# Loss: 6.7538e-01, Accuracy:   0.71, Validation Loss: 8.8500e-01, Validation Accuracy:   0.58
# Epoch 25/50
# Loss: 6.7444e-01, Accuracy:   0.72, Validation Loss: 8.8722e-01, Validation Accuracy:   0.57
# Epoch 26/50
# Loss: 6.7290e-01, Accuracy:   0.72, Validation Loss: 9.4144e-01, Validation Accuracy:   0.55
# Epoch 27/50
# Loss: 6.7110e-01, Accuracy:   0.72, Validation Loss: 8.5813e-01, Validation Accuracy:   0.58
# Epoch 28/50
# Loss: 6.7105e-01, Accuracy:   0.72, Validation Loss: 8.7101e-01, Validation Accuracy:   0.56
# Epoch 29/50
# Loss: 6.7067e-01, Accuracy:   0.72, Validation Loss: 8.3340e-01, Validation Accuracy:   0.61
# Epoch 30/50
# Loss: 6.6846e-01, Accuracy:   0.72, Validation Loss: 9.3904e-01, Validation Accuracy:   0.55
# Epoch 31/50
# Loss: 6.6823e-01, Accuracy:   0.72, Validation Loss: 8.2266e-01, Validation Accuracy:   0.60
# Epoch 32/50
# Loss: 6.6910e-01, Accuracy:   0.72, Validation Loss: 9.0902e-01, Validation Accuracy:   0.58
# Epoch 33/50
# Loss: 6.6776e-01, Accuracy:   0.72, Validation Loss: 8.7811e-01, Validation Accuracy:   0.58
# Epoch 34/50
# Loss: 6.6795e-01, Accuracy:   0.72, Validation Loss: 8.4924e-01, Validation Accuracy:   0.60
# Epoch 35/50
# Loss: 6.6662e-01, Accuracy:   0.72, Validation Loss: 8.4305e-01, Validation Accuracy:   0.58
# Epoch 36/50
# Loss: 6.6693e-01, Accuracy:   0.72, Validation Loss: 8.6674e-01, Validation Accuracy:   0.58
# Epoch 37/50
# Loss: 6.6428e-01, Accuracy:   0.72, Validation Loss: 9.0148e-01, Validation Accuracy:   0.57
# Epoch 38/50
# Loss: 6.6543e-01, Accuracy:   0.72, Validation Loss: 9.1641e-01, Validation Accuracy:   0.56
# Epoch 39/50
# Loss: 6.6476e-01, Accuracy:   0.72, Validation Loss: 8.4990e-01, Validation Accuracy:   0.60
# Epoch 40/50
# Loss: 6.6496e-01, Accuracy:   0.72, Validation Loss: 9.1814e-01, Validation Accuracy:   0.55
# Epoch 41/50
# Loss: 6.6401e-01, Accuracy:   0.72, Validation Loss: 9.5506e-01, Validation Accuracy:   0.55
# Epoch 42/50
# Loss: 6.6416e-01, Accuracy:   0.72, Validation Loss: 8.0388e-01, Validation Accuracy:   0.60
# Epoch 43/50
# Loss: 6.6503e-01, Accuracy:   0.72, Validation Loss: 9.2033e-01, Validation Accuracy:   0.55
# Epoch 44/50
# Loss: 6.6323e-01, Accuracy:   0.72, Validation Loss: 9.1357e-01, Validation Accuracy:   0.56
# Epoch 45/50
# Loss: 6.6253e-01, Accuracy:   0.72, Validation Loss: 9.5525e-01, Validation Accuracy:   0.53
# Epoch 46/50
# Loss: 6.6362e-01, Accuracy:   0.72, Validation Loss: 8.5707e-01, Validation Accuracy:   0.58
# Epoch 47/50
# Loss: 6.6186e-01, Accuracy:   0.72, Validation Loss: 8.3017e-01, Validation Accuracy:   0.59
# Epoch 48/50
# Loss: 6.6144e-01, Accuracy:   0.72, Validation Loss: 9.5485e-01, Validation Accuracy:   0.55
# Epoch 49/50
# Loss: 6.6041e-01, Accuracy:   0.72, Validation Loss: 8.7111e-01, Validation Accuracy:   0.58
# Epoch 50/50
# Loss: 6.6136e-01, Accuracy:   0.72, Validation Loss: 9.5450e-01, Validation Accuracy:   0.56
# Test - Final Model
# Test Loss: 8.6440e-01, Test Accuracy:   0.61
# Test - Best Model
# Test Loss: 8.2358e-01, Test Accuracy:   0.62
